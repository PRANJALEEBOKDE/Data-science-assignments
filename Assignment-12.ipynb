# %% [markdown]
#  # EDA2

# %% [markdown]
# ## 1. Data Exploration and Preprocessing:

# %%
import pandas as pd 
data=pd.read_csv(r"C:\Users\dipak\Desktop\Pranjalee Bokade\assignments\EDA2\adult_with_headers.csv")
data.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
data.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
data=data[data.duplicated()]
data
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22300   25            Private  195994        1st-4th              2
# 22367   44            Private  367749      Bachelors             13
# 22494   49   Self-emp-not-inc   43479   Some-college             10
# 25872   23            Private  240137        5th-6th              3
# 26313   28            Private  274679        Masters             14
# 28230   27            Private  255582        HS-grad              9
# 28522   42            Private  204235   Some-college             10
# 28846   39            Private   30916        HS-grad              9
# 29157   38            Private  207202        HS-grad              9
# 30845   46            Private  133616   Some-college             10
# 31993   19            Private  251579   Some-college             10
# 32404   35            Private  379959        HS-grad              9
#
#             marital_status          occupation    relationship  \
# 4881         Never-married        Craft-repair   Not-in-family
# 5104         Never-married       Other-service   Not-in-family
# 9171         Never-married      Prof-specialty       Own-child
# 11631        Never-married        Tech-support   Not-in-family
# 13084        Never-married     Priv-house-serv   Not-in-family
# 15059        Never-married     Farming-fishing   Not-in-family
# 17040   Married-civ-spouse        Craft-repair         Husband
# 18555        Never-married       Other-service   Not-in-family
# 18698        Never-married     Farming-fishing   Not-in-family
# 21318        Never-married        Adm-clerical       Own-child
# 21490        Never-married     Exec-managerial       Own-child
# 21875   Married-civ-spouse        Craft-repair         Husband
# 22300        Never-married     Priv-house-serv   Not-in-family
# 22367        Never-married      Prof-specialty   Not-in-family
# 22494   Married-civ-spouse        Craft-repair         Husband
# 25872        Never-married   Handlers-cleaners   Not-in-family
# 26313        Never-married      Prof-specialty   Not-in-family
# 28230        Never-married   Machine-op-inspct   Not-in-family
# 28522   Married-civ-spouse      Prof-specialty         Husband
# 28846   Married-civ-spouse        Craft-repair         Husband
# 29157   Married-civ-spouse   Machine-op-inspct         Husband
# 30845             Divorced        Adm-clerical       Unmarried
# 31993        Never-married       Other-service       Own-child
# 32404             Divorced       Other-service   Not-in-family
#
#                       race      sex  capital_gain  capital_loss  \
# 4881                 White     Male             0             0
# 5104    Asian-Pac-Islander     Male             0             0
# 9171                 White   Female             0             0
# 11631                White   Female             0             0
# 13084                White   Female             0             0
# 15059                White     Male             0             0
# 17040                White     Male             0             0
# 18555                Black     Male             0             0
# 18698                White     Male             0             0
# 21318                White   Female             0             0
# 21490                Black     Male             0             0
# 21875                White     Male             0             0
# 22300                White   Female             0             0
# 22367                White   Female             0             0
# 22494                White     Male             0             0
# 25872                White     Male             0             0
# 26313                White     Male             0             0
# 28230                White   Female             0             0
# 28522                White     Male             0             0
# 28846                White     Male             0             0
# 29157                White     Male             0             0
# 30845                White   Female             0             0
# 31993                White     Male             0             0
# 32404                White   Female             0             0
#
#        hours_per_week  native_country  income
# 4881               40          Mexico   <=50K
# 5104               35   United-States   <=50K
# 9171               10   United-States   <=50K
# 11631              10   United-States   <=50K
# 13084              40       Guatemala   <=50K
# 15059              50          Mexico   <=50K
# 17040              40   United-States   <=50K
# 18555              40               ?   <=50K
# 18698              40   United-States   <=50K
# 21318              10   United-States   <=50K
# 21490              30   United-States   <=50K
# 21875              40   United-States   <=50K
# 22300              40       Guatemala   <=50K
# 22367              45          Mexico   <=50K
# 22494              40   United-States   <=50K
# 25872              55          Mexico   <=50K
# 26313              50   United-States   <=50K
# 28230              40   United-States   <=50K
# 28522              40   United-States    >50K
# 28846              40   United-States   <=50K
# 29157              48   United-States    >50K
# 30845              40   United-States   <=50K
# 31993              14   United-States   <=50K
# 32404              40   United-States   <=50K

# %%
data=data.drop_duplicates()
data
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22367   44            Private  367749      Bachelors             13
# 22494   49   Self-emp-not-inc   43479   Some-college             10
# 25872   23            Private  240137        5th-6th              3
# 26313   28            Private  274679        Masters             14
# 28230   27            Private  255582        HS-grad              9
# 28522   42            Private  204235   Some-college             10
# 28846   39            Private   30916        HS-grad              9
# 29157   38            Private  207202        HS-grad              9
# 30845   46            Private  133616   Some-college             10
# 31993   19            Private  251579   Some-college             10
# 32404   35            Private  379959        HS-grad              9
#
#             marital_status          occupation    relationship  \
# 4881         Never-married        Craft-repair   Not-in-family
# 5104         Never-married       Other-service   Not-in-family
# 9171         Never-married      Prof-specialty       Own-child
# 11631        Never-married        Tech-support   Not-in-family
# 13084        Never-married     Priv-house-serv   Not-in-family
# 15059        Never-married     Farming-fishing   Not-in-family
# 17040   Married-civ-spouse        Craft-repair         Husband
# 18555        Never-married       Other-service   Not-in-family
# 18698        Never-married     Farming-fishing   Not-in-family
# 21318        Never-married        Adm-clerical       Own-child
# 21490        Never-married     Exec-managerial       Own-child
# 21875   Married-civ-spouse        Craft-repair         Husband
# 22367        Never-married      Prof-specialty   Not-in-family
# 22494   Married-civ-spouse        Craft-repair         Husband
# 25872        Never-married   Handlers-cleaners   Not-in-family
# 26313        Never-married      Prof-specialty   Not-in-family
# 28230        Never-married   Machine-op-inspct   Not-in-family
# 28522   Married-civ-spouse      Prof-specialty         Husband
# 28846   Married-civ-spouse        Craft-repair         Husband
# 29157   Married-civ-spouse   Machine-op-inspct         Husband
# 30845             Divorced        Adm-clerical       Unmarried
# 31993        Never-married       Other-service       Own-child
# 32404             Divorced       Other-service   Not-in-family
#
#                       race      sex  capital_gain  capital_loss  \
# 4881                 White     Male             0             0
# 5104    Asian-Pac-Islander     Male             0             0
# 9171                 White   Female             0             0
# 11631                White   Female             0             0
# 13084                White   Female             0             0
# 15059                White     Male             0             0
# 17040                White     Male             0             0
# 18555                Black     Male             0             0
# 18698                White     Male             0             0
# 21318                White   Female             0             0
# 21490                Black     Male             0             0
# 21875                White     Male             0             0
# 22367                White   Female             0             0
# 22494                White     Male             0             0
# 25872                White     Male             0             0
# 26313                White     Male             0             0
# 28230                White   Female             0             0
# 28522                White     Male             0             0
# 28846                White     Male             0             0
# 29157                White     Male             0             0
# 30845                White   Female             0             0
# 31993                White     Male             0             0
# 32404                White   Female             0             0
#
#        hours_per_week  native_country  income
# 4881               40          Mexico   <=50K
# 5104               35   United-States   <=50K
# 9171               10   United-States   <=50K
# 11631              10   United-States   <=50K
# 13084              40       Guatemala   <=50K
# 15059              50          Mexico   <=50K
# 17040              40   United-States   <=50K
# 18555              40               ?   <=50K
# 18698              40   United-States   <=50K
# 21318              10   United-States   <=50K
# 21490              30   United-States   <=50K
# 21875              40   United-States   <=50K
# 22367              45          Mexico   <=50K
# 22494              40   United-States   <=50K
# 25872              55          Mexico   <=50K
# 26313              50   United-States   <=50K
# 28230              40   United-States   <=50K
# 28522              40   United-States    >50K
# 28846              40   United-States   <=50K
# 29157              48   United-States    >50K
# 30845              40   United-States   <=50K
# 31993              14   United-States   <=50K
# 32404              40   United-States   <=50K

# %% [markdown]
# ## 2. Encoding Techniques:

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler,LabelEncoder

# Select only numerical features for scaling
numerical_features = data.select_dtypes(include=['float64', 'int64']).columns

# Standard Scaling
standard_scaler = StandardScaler()
data_standard_scaled = data.copy()
data_standard_scaled[numerical_features] = standard_scaler.fit_transform(data[numerical_features])

# Display the first few rows of the Standard Scaled dataframe
print("\nStandard Scaled DataFrame:")
print(data_standard_scaled.head())
# Out:
# Standard Scaled DataFrame:
#             age workclass    fnlwgt      education  education_num  \
# 4881  -0.540430   Private  1.242133      Bachelors       1.293993
# 5104   3.519583   Private -1.358711   Some-college       0.363936
# 9171  -0.790277   Private  0.651376   Some-college       0.363936
# 11631 -0.852738   Private -0.796641   Some-college       0.363936
# 13084 -0.540430   Private  0.101662        1st-4th      -2.116218
#
#        marital_status        occupation    relationship                 race  \
# 4881    Never-married      Craft-repair   Not-in-family                White
# 5104    Never-married     Other-service   Not-in-family   Asian-Pac-Islander
# 9171    Never-married    Prof-specialty       Own-child                White
# 11631   Never-married      Tech-support   Not-in-family                White
# 13084   Never-married   Priv-house-serv   Not-in-family                White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 4881      Male           0.0           0.0        0.283927          Mexico
# 5104      Male           0.0           0.0       -0.109466   United-States
# 9171    Female           0.0           0.0       -2.076431   United-States
# 11631   Female           0.0           0.0       -2.076431   United-States
# 13084   Female           0.0           0.0        0.283927       Guatemala
#
#        income
# 4881    <=50K
# 5104    <=50K
# 9171    <=50K
# 11631   <=50K
# 13084   <=50K

# %%
# Min-Max Scaling
min_max_scaler = MinMaxScaler()
data_min_max_scaled = data.copy()
data_min_max_scaled[numerical_features] = min_max_scaler.fit_transform(data[numerical_features])

# Display the first few rows of the Min-Max Scaled dataframe
print("\nMin-Max Scaled DataFrame:")
print(data_min_max_scaled.head())
# Out:
# Min-Max Scaled DataFrame:
#             age workclass    fnlwgt      education  education_num  \
# 4881   0.084507   Private  0.794252      Bachelors       0.923077
# 5104   1.000000   Private  0.061511   Some-college       0.692308
# 9171   0.028169   Private  0.627817   Some-college       0.692308
# 11631  0.014085   Private  0.219864   Some-college       0.692308
# 13084  0.084507   Private  0.472945        1st-4th       0.076923
#
#        marital_status        occupation    relationship                 race  \
# 4881    Never-married      Craft-repair   Not-in-family                White
# 5104    Never-married     Other-service   Not-in-family   Asian-Pac-Islander
# 9171    Never-married    Prof-specialty       Own-child                White
# 11631   Never-married      Tech-support   Not-in-family                White
# 13084   Never-married   Priv-house-serv   Not-in-family                White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 4881      Male           0.0           0.0        0.666667          Mexico
# 5104      Male           0.0           0.0        0.555556   United-States
# 9171    Female           0.0           0.0        0.000000   United-States
# 11631   Female           0.0           0.0        0.000000   United-States
# 13084   Female           0.0           0.0        0.666667       Guatemala
#
#        income
# 4881    <=50K
# 5104    <=50K
# 9171    <=50K
# 11631   <=50K
# 13084   <=50K

# %% [markdown]
# ## 3: Feature Engineering:

# %%
import pandas as pd
categorical_columns = data.select_dtypes(include=['object']).columns
# Apply One-Hot Encoding to categorical variables with less than 5 unique categories
for col in categorical_columns:
    if data[col].nunique() < 5:
        data= pd.get_dummies(data, columns=[col], prefix=[col], drop_first=True)
# Display the first few rows of the dataframe after One-Hot Encoding
print("\nDataFrame after One-Hot Encoding:")
print(data.head())
# Out:
# DataFrame after One-Hot Encoding:
#        age  fnlwgt      education  education_num        occupation  \
# 4881    25  308144      Bachelors             13      Craft-repair
# 5104    90   52386   Some-college             10     Other-service
# 9171    21  250051   Some-college             10    Prof-specialty
# 11631   20  107658   Some-college             10      Tech-support
# 13084   25  195994        1st-4th              2   Priv-house-serv
#
#        capital_gain  capital_loss  hours_per_week  \
# 4881              0             0              40
# 5104              0             0              35
# 9171              0             0              10
# 11631             0             0              10
# 13084             0             0              40
#
#        workclass_ Self-emp-not-inc  marital_status_ Married-civ-spouse  ...  \
# 4881                             0                                   0  ...
# 5104                             0                                   0  ...
# 9171                             0                                   0  ...
# 11631                            0                                   0  ...
# 13084                            0                                   0  ...
#
#        relationship_ Not-in-family  relationship_ Own-child  \
# 4881                             1                        0
# 5104                             1                        0
# 9171                             0                        1
# 11631                            1                        0
# 13084                            1                        0
#
#        relationship_ Unmarried  race_ Black  race_ White  sex_ Male  \
# 4881                         0            0            1          1
# 5104                         0            0            0          1
# 9171                         0            0            1          0
# 11631                        0            0            1          0
# 13084                        0            0            1          0
#
#        native_country_ Guatemala  native_country_ Mexico  \
# 4881                           0                       1
# 5104                           0                       0
# 9171                           0                       0
# 11631                          0                       0
# 13084                          1                       0
#
#        native_country_ United-States  income_ >50K
# 4881                               0             0
# 5104                               1             0
# 9171                               1             0
# 11631                              1             0
# 13084                              0             0
#
# [5 rows x 21 columns]

# %%
categories_to_encode = data.select_dtypes(include=['object']).columns  # Select categorical columns
for col in categories_to_encode:
    if data[col].nunique() >5:# Check number of unique categories
        label_encoder = LabelEncoder()
        data[col] = label_encoder.fit_transform(data[col])

# Display the DataFrame after Label Encoding
print("\nDataFrame after Label Encoding:")
print(data)
# Out:
# DataFrame after Label Encoding:
#        age          workclass  fnlwgt  education  education_num  \
# 4881    25            Private  308144          3             13
# 5104    90            Private   52386          7             10
# 9171    21            Private  250051          7             10
# 11631   20            Private  107658          7             10
# 13084   25            Private  195994          0              2
# 15059   21            Private  243368          6              1
# 17040   46            Private  173243          4              9
# 18555   30            Private  144593          4              9
# 18698   19            Private   97261          4              9
# 21318   19            Private  138153          7             10
# 21490   19            Private  146679          7             10
# 21875   49            Private   31267          2              4
# 22367   44            Private  367749          3             13
# 22494   49   Self-emp-not-inc   43479          7             10
# 25872   23            Private  240137          1              3
# 26313   28            Private  274679          5             14
# 28230   27            Private  255582          4              9
# 28522   42            Private  204235          7             10
# 28846   39            Private   30916          4              9
# 29157   38            Private  207202          4              9
# 30845   46            Private  133616          7             10
# 31993   19            Private  251579          7             10
# 32404   35            Private  379959          4              9
#
#             marital_status  occupation    relationship                 race  \
# 4881         Never-married           1   Not-in-family                White
# 5104         Never-married           6   Not-in-family   Asian-Pac-Islander
# 9171         Never-married           8       Own-child                White
# 11631        Never-married           9   Not-in-family                White
# 13084        Never-married           7   Not-in-family                White
# 15059        Never-married           3   Not-in-family                White
# 17040   Married-civ-spouse           1         Husband                White
# 18555        Never-married           6   Not-in-family                Black
# 18698        Never-married           3   Not-in-family                White
# 21318        Never-married           0       Own-child                White
# 21490        Never-married           2       Own-child                Black
# 21875   Married-civ-spouse           1         Husband                White
# 22367        Never-married           8   Not-in-family                White
# 22494   Married-civ-spouse           1         Husband                White
# 25872        Never-married           4   Not-in-family                White
# 26313        Never-married           8   Not-in-family                White
# 28230        Never-married           5   Not-in-family                White
# 28522   Married-civ-spouse           8         Husband                White
# 28846   Married-civ-spouse           1         Husband                White
# 29157   Married-civ-spouse           5         Husband                White
# 30845             Divorced           0       Unmarried                White
# 31993        Never-married           6       Own-child                White
# 32404             Divorced           6   Not-in-family                White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 4881      Male             0             0              40          Mexico
# 5104      Male             0             0              35   United-States
# 9171    Female             0             0              10   United-States
# 11631   Female             0             0              10   United-States
# 13084   Female             0             0              40       Guatemala
# 15059     Male             0             0              50          Mexico
# 17040     Male             0             0              40   United-States
# 18555     Male             0             0              40               ?
# 18698     Male             0             0              40   United-States
# 21318   Female             0             0              10   United-States
# 21490     Male             0             0              30   United-States
# 21875     Male             0             0              40   United-States
# 22367   Female             0             0              45          Mexico
# 22494     Male             0             0              40   United-States
# 25872     Male             0             0              55          Mexico
# 26313     Male             0             0              50   United-States
# 28230   Female             0             0              40   United-States
# 28522     Male             0             0              40   United-States
# 28846     Male             0             0              40   United-States
# 29157     Male             0             0              48   United-States
# 30845   Female             0             0              40   United-States
# 31993     Male             0             0              14   United-States
# 32404   Female             0             0              40   United-States
#
#        income
# 4881    <=50K
# 5104    <=50K
# 9171    <=50K
# 11631   <=50K
# 13084   <=50K
# 15059   <=50K
# 17040   <=50K
# 18555   <=50K
# 18698   <=50K
# 21318   <=50K
# 21490   <=50K
# 21875   <=50K
# 22367   <=50K
# 22494   <=50K
# 25872   <=50K
# 26313   <=50K
# 28230   <=50K
# 28522    >50K
# 28846   <=50K
# 29157    >50K
# 30845   <=50K
# 31993   <=50K
# 32404   <=50K
# C:\Users\dipak\AppData\Local\Temp\ipykernel_20080\2679484061.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = label_encoder.fit_transform(data[col])
# C:\Users\dipak\AppData\Local\Temp\ipykernel_20080\2679484061.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = label_encoder.fit_transform(data[col])

# %%
import matplotlib.pyplot as plt
# Plot histogram to visualize the distribution
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.hist(data['fnlwgt'], bins=10, edgecolor='black')
plt.title('Histogram of Skewed Feature')
plt.xlabel('Values')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Apply log transformation
import numpy as np
data['log_feature1'] = np.log(data['fnlwgt'])
data['log_feature1']
# Out:
# C:\Users\dipak\AppData\Local\Temp\ipykernel_20080\2778580008.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['log_feature1'] = np.log(data['fnlwgt'])
# 4881     12.638322
# 5104     10.866395
# 9171     12.429420
# 11631    11.586715
# 13084    12.185839
# 15059    12.402330
# 17040    12.062451
# 18555    11.881678
# 18698    11.485153
# 21318    11.836117
# 21490    11.896002
# 21875    10.350319
# 22367    12.815156
# 22494    10.680033
# 25872    12.388965
# 26313    12.523358
# 28230    12.451299
# 28522    12.227027
# 28846    10.339029
# 29157    12.241449
# 30845    11.802725
# 31993    12.435512
# 32404    12.847819
# Name: log_feature1, dtype: float64

# %%
# Plot histogram of log-transformed feature
plt.subplot(1, 2, 2)
plt.hist(data['log_feature1'], bins=10, edgecolor='black')
plt.title('Histogram of Log-Transformed Feature')
plt.xlabel('Log Values')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
#  ## 4. Feature Selection:

# %%
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import OneHotEncoder
import pandas as pd


# Apply one-hot encoding to categorical variables
data_encoded = pd.get_dummies(data)

# Remove non-numeric columns (if any)
data_numeric = data_encoded.select_dtypes(include=[np.number])

# Identify outliers using Isolation Forest
clf = IsolationForest(contamination=0.05, random_state=42)
outlier_preds = clf.fit_predict(data_numeric.dropna())

# Create a mask to identify outliers
outlier_mask = outlier_preds == -1

# Remove outliers from the dataframe
data_no_outliers = data_numeric.loc[~outlier_mask]

# Display the dataframe after removing outliers
print("\nDataFrame after removing outliers:")
print(data_no_outliers)
# Out:
# DataFrame after removing outliers:
#        age  fnlwgt  education  education_num  occupation  capital_gain  \
# 4881    25  308144          3             13           1             0
# 5104    90   52386          7             10           6             0
# 9171    21  250051          7             10           8             0
# 11631   20  107658          7             10           9             0
# 15059   21  243368          6              1           3             0
# 17040   46  173243          4              9           1             0
# 18555   30  144593          4              9           6             0
# 18698   19   97261          4              9           3             0
# 21318   19  138153          7             10           0             0
# 21490   19  146679          7             10           2             0
# 21875   49   31267          2              4           1             0
# 22367   44  367749          3             13           8             0
# 25872   23  240137          1              3           4             0
# 26313   28  274679          5             14           8             0
# 28230   27  255582          4              9           5             0
# 28522   42  204235          7             10           8             0
# 28846   39   30916          4              9           1             0
# 29157   38  207202          4              9           5             0
# 30845   46  133616          7             10           0             0
# 31993   19  251579          7             10           6             0
# 32404   35  379959          4              9           6             0
#
#        capital_loss  hours_per_week  log_feature1  workclass_ Private  ...  \
# 4881              0              40     12.638322                   1  ...
# 5104              0              35     10.866395                   1  ...
# 9171              0              10     12.429420                   1  ...
# 11631             0              10     11.586715                   1  ...
# 15059             0              50     12.402330                   1  ...
# 17040             0              40     12.062451                   1  ...
# 18555             0              40     11.881678                   1  ...
# 18698             0              40     11.485153                   1  ...
# 21318             0              10     11.836117                   1  ...
# 21490             0              30     11.896002                   1  ...
# 21875             0              40     10.350319                   1  ...
# 22367             0              45     12.815156                   1  ...
# 25872             0              55     12.388965                   1  ...
# 26313             0              50     12.523358                   1  ...
# 28230             0              40     12.451299                   1  ...
# 28522             0              40     12.227027                   1  ...
# 28846             0              40     10.339029                   1  ...
# 29157             0              48     12.241449                   1  ...
# 30845             0              40     11.802725                   1  ...
# 31993             0              14     12.435512                   1  ...
# 32404             0              40     12.847819                   1  ...
#
#        race_ Black  race_ White  sex_ Female  sex_ Male  native_country_ ?  \
# 4881             0            1            0          1                  0
# 5104             0            0            0          1                  0
# 9171             0            1            1          0                  0
# 11631            0            1            1          0                  0
# 15059            0            1            0          1                  0
# 17040            0            1            0          1                  0
# 18555            1            0            0          1                  1
# 18698            0            1            0          1                  0
# 21318            0            1            1          0                  0
# 21490            1            0            0          1                  0
# 21875            0            1            0          1                  0
# 22367            0            1            1          0                  0
# 25872            0            1            0          1                  0
# 26313            0            1            0          1                  0
# 28230            0            1            1          0                  0
# 28522            0            1            0          1                  0
# 28846            0            1            0          1                  0
# 29157            0            1            0          1                  0
# 30845            0            1            1          0                  0
# 31993            0            1            0          1                  0
# 32404            0            1            1          0                  0
#
#        native_country_ Guatemala  native_country_ Mexico  \
# 4881                           0                       1
# 5104                           0                       0
# 9171                           0                       0
# 11631                          0                       0
# 15059                          0                       1
# 17040                          0                       0
# 18555                          0                       0
# 18698                          0                       0
# 21318                          0                       0
# 21490                          0                       0
# 21875                          0                       0
# 22367                          0                       1
# 25872                          0                       1
# 26313                          0                       0
# 28230                          0                       0
# 28522                          0                       0
# 28846                          0                       0
# 29157                          0                       0
# 30845                          0                       0
# 31993                          0                       0
# 32404                          0                       0
#
#        native_country_ United-States  income_ <=50K  income_ >50K
# 4881                               0              1             0
# 5104                               1              1             0
# 9171                               1              1             0
# 11631                              1              1             0
# 15059                              0              1             0
# 17040                              1              1             0
# 18555                              0              1             0
# 18698                              1              1             0
# 21318                              1              1             0
# 21490                              1              1             0
# 21875                              1              1             0
# 22367                              0              1             0
# 25872                              0              1             0
# 26313                              1              1             0
# 28230                              1              1             0
# 28522                              1              0             1
# 28846                              1              1             0
# 29157                              1              0             1
# 30845                              1              1             0
# 31993                              1              1             0
# 32404                              1              1             0
#
# [21 rows x 29 columns]
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(

# %%
import ppscore as pps
pps_matrix = pps.matrix(data)
pps_matrix
# Out:
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   warnings.warn(
# C:\Users\dipak\OneDrive\Documents\Lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=4.
#   warnings.warn(
#                 x               y   ppscore                case  \
# 0             age             age  1.000000      predict_itself
# 1             age       workclass  0.000000      classification
# 2             age          fnlwgt  0.022213          regression
# 3             age       education  0.000000          regression
# 4             age   education_num  0.000000          regression
# ..            ...             ...       ...                 ...
# 251  log_feature1    capital_loss  0.000000  target_is_constant
# 252  log_feature1  hours_per_week  0.000000          regression
# 253  log_feature1  native_country  0.095841      classification
# 254  log_feature1          income  0.711681      classification
# 255  log_feature1    log_feature1  1.000000      predict_itself
#
#      is_valid_score               metric  baseline_score   model_score  \
# 0              True                 None        0.000000      1.000000
# 1              True          weighted F1        0.935266      0.916667
# 2              True  mean absolute error    81888.434783  80069.477778
# 3              True  mean absolute error        1.782609      2.502083
# 4              True  mean absolute error        2.043478      3.935417
# ..              ...                  ...             ...           ...
# 251            True                 None        1.000000      1.000000
# 252            True  mean absolute error        7.782609     16.366667
# 253            True          weighted F1        0.628261      0.663889
# 254            True          weighted F1        0.871542      0.962963
# 255            True                 None        0.000000      1.000000
#
#                         model
# 0                        None
# 1    DecisionTreeClassifier()
# 2     DecisionTreeRegressor()
# 3     DecisionTreeRegressor()
# 4     DecisionTreeRegressor()
# ..                        ...
# 251                      None
# 252   DecisionTreeRegressor()
# 253  DecisionTreeClassifier()
# 254  DecisionTreeClassifier()
# 255                      None
#
# [256 rows x 9 columns]

# %%
# Calculate the correlation matrix (Pearson correlation)
import seaborn as sns
correlation_matrix = data.corr(numeric_only=True)

# Display the correlation matrix
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                      age    fnlwgt  education  education_num  occupation  \
# age             1.000000 -0.351317   0.090074       0.125960   -0.064573
# fnlwgt         -0.351317  1.000000  -0.217379       0.168972    0.430514
# education       0.090074 -0.217379   1.000000       0.432269    0.008620
# education_num   0.125960  0.168972   0.432269       1.000000    0.143824
# occupation     -0.064573  0.430514   0.008620       0.143824    1.000000
# capital_gain         NaN       NaN        NaN            NaN         NaN
# capital_loss         NaN       NaN        NaN            NaN         NaN
# hours_per_week  0.260277  0.159010  -0.561417      -0.260288   -0.127142
# log_feature1   -0.466046  0.939653  -0.117841       0.136148    0.437324
#
#                 capital_gain  capital_loss  hours_per_week  log_feature1
# age                      NaN           NaN        0.260277     -0.466046
# fnlwgt                   NaN           NaN        0.159010      0.939653
# education                NaN           NaN       -0.561417     -0.117841
# education_num            NaN           NaN       -0.260288      0.136148
# occupation               NaN           NaN       -0.127142      0.437324
# capital_gain             NaN           NaN             NaN           NaN
# capital_loss             NaN           NaN             NaN           NaN
# hours_per_week           NaN           NaN        1.000000      0.071183
# log_feature1             NaN           NaN        0.071183      1.000000

# %%
# Plotting the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
